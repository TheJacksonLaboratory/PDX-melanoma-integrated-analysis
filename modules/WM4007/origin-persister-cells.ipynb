# %%
from IPython.display import display, HTML, Image
display(HTML("<style>.container { width:95% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
import copy
import numpy as np
import pandas as pd
import scanpy as sc
import scanpy.external as sce
import networkx as nx
import phate
import scvelo as scv

import matplotlib
from matplotlib import cm
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import scipy.cluster.hierarchy
from scipy.spatial.distance import cdist, pdist, squareform
from scipy import ndimage
from scipy.sparse import csr_matrix
import scipy.stats
from sklearn.cluster import KMeans

from scanpy.tools._score_genes import score_genes

from scipy.interpolate import UnivariateSpline
from scipy.ndimage import gaussian_filter

import sys
sys.path.append("../../lib")
from stpalette import palette1
from utils import loadCNVfromCaSpER, loadCNVfromInferCNV

import scFates as scf

from pathways import genesDicts
# Out:
# <style>.container { width:95% !important; }</style>

# %%
model = 'WM4007'

dataPath = '../../data/'
preprocessedCasperCNVDataPath = 'c:/Projects/A_ST/output_casper_%s/' % model
preprocessedInferCNVDataPath = 'c:/Projects/A_ST/inferCNV_results_%s/' % model

ids = sorted(np.loadtxt(dataPath + 'ids_%s_ST.txt' % model, dtype=str))
sids = [id[7:12] for id in ids]

palette1.update({sid: cm.terrain(0.01 + i/len(sids)) for i, sid in enumerate(sids)})

# %%
df_infercnv_cnv, df_infercnv_meta = loadCNVfromInferCNV(dataPath + 'For_inferCNV_%s_meta.data.tsv.gz' % model, 
                                                        [preprocessedInferCNVDataPath + 'infercnv.references.txt',
                                                         preprocessedInferCNVDataPath + 'infercnv.observations.txt'])
# Out:
# (8625, 11935) (11982, 3)

# %% [markdown]
# # Load ad_all

# %%
ad_all = sc.read(dataPath + 'ad_all_human_clustered_st_%s.h5ad' % model)
print(ad_all.shape)

preprocessedStDataPath = 'c:/Projects/A_ST/from HPCC 11 28 2022/results_NF1-nod-t2t-k35/%s/' % model
ads = {id: ad_all[ad_all.obs['sample']==id, :] for id in ids}
images = {id: sc.read(preprocessedStDataPath + '%s/st_adata_processed.h5ad' % id).uns['spatial'] for id in ids}
for sample in ids[:]:
    ads[sample] = ad_all[ad_all.obs['sample']==sample, :].copy()    
    ads[sample].uns['spatial'] = images[sample]
# Out:
# (11990, 17788)

# %% [markdown]
# # Least and most similar persisters

# %%
# Looking for subset of T0 which are similar to T1
df0 = df_infercnv_cnv.copy()
df0.columns = pd.MultiIndex.from_frame(df_infercnv_meta.loc[df_infercnv_cnv.columns].reset_index().rename({'index': 'spot'}, axis=1))
df1 = df0.groupby(level=['time', 'cluster'], axis=1).mean()[[('T1', '2'), ('T1', '3'), ('T1', '4')]]
df0 = df0.xs('T0', level='time', axis=1)
print(df0.shape, df1.shape)

def tempf(cl):
    se = pd.DataFrame(index=df0.columns, columns=df1.columns, data=cdist(df0.values.T, df1.values.T, metric='correlation')).droplevel(0, axis=1)[cl].sort_values()
    top_most_similar_i_r = se[:200].index.get_level_values(0)
    top_least_similar_i_r = se[-200:].index.get_level_values(0)

    ni = 'sel_sim_i_r'
    ad_all.obs[ni] = 'other'
    ad_all.obs.loc[ad_all.obs.index.isin(top_most_similar_i_r), ni] = 'top_most_similar'
    ad_all.obs.loc[ad_all.obs.index.isin(top_least_similar_i_r), ni] = 'top_least_similar'

    return pd.crosstab(ad_all.obs[ad_all.obs['T']=='T0'][ni], ad_all.obs[ad_all.obs['T']=='T0']['cluster']).T.style.background_gradient(axis=0)

def tempf2(cl):
    se = pd.DataFrame(index=df0.columns, columns=df1.columns, data=cdist(df0.values.T, df1.values.T, metric='correlation')).droplevel(0, axis=1)[cl].sort_values()
    top_most_similar_i_r = se[:200].index.get_level_values(0)
    top_least_similar_i_r = se[-200:].index.get_level_values(0)
    return top_most_similar_i_r, top_least_similar_i_r
# Out:
# (8625, 2785) (8625, 3)

# %%
top_most_similar_i_r, top_least_similar_i_r = tempf2('3')
tempf('3')
# Out:
# <style type="text/css">
# #T_fa5e4_row0_col0 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_fa5e4_row0_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_fa5e4_row0_col2 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_fa5e4_row1_col0, #T_fa5e4_row1_col1, #T_fa5e4_row3_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fa5e4_row1_col2 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_fa5e4_row2_col0, #T_fa5e4_row2_col1, #T_fa5e4_row4_col0, #T_fa5e4_row4_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_fa5e4_row2_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_fa5e4_row3_col0 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_fa5e4_row3_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_fa5e4_row4_col1, #T_fa5e4_row5_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_fa5e4_row5_col0, #T_fa5e4_row5_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# </style>
# <table id="T_fa5e4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >sel_sim_i_r</th>
#       <th id="T_fa5e4_level0_col0" class="col_heading level0 col0" >other</th>
#       <th id="T_fa5e4_level0_col1" class="col_heading level0 col1" >top_least_similar</th>
#       <th id="T_fa5e4_level0_col2" class="col_heading level0 col2" >top_most_similar</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa5e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa5e4_row0_col0" class="data row0 col0" >874</td>
#       <td id="T_fa5e4_row0_col1" class="data row0 col1" >50</td>
#       <td id="T_fa5e4_row0_col2" class="data row0 col2" >62</td>
#     </tr>
#     <tr>
#       <th id="T_fa5e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa5e4_row1_col0" class="data row1 col0" >996</td>
#       <td id="T_fa5e4_row1_col1" class="data row1 col1" >119</td>
#       <td id="T_fa5e4_row1_col2" class="data row1 col2" >49</td>
#     </tr>
#     <tr>
#       <th id="T_fa5e4_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_fa5e4_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_fa5e4_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_fa5e4_row2_col2" class="data row2 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fa5e4_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_fa5e4_row3_col0" class="data row3 col0" >403</td>
#       <td id="T_fa5e4_row3_col1" class="data row3 col1" >29</td>
#       <td id="T_fa5e4_row3_col2" class="data row3 col2" >78</td>
#     </tr>
#     <tr>
#       <th id="T_fa5e4_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_fa5e4_row4_col0" class="data row4 col0" >9</td>
#       <td id="T_fa5e4_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_fa5e4_row4_col2" class="data row4 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fa5e4_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_fa5e4_row5_col0" class="data row5 col0" >96</td>
#       <td id="T_fa5e4_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_fa5e4_row5_col2" class="data row5 col2" >8</td>
#     </tr>
#   </tbody>
# </table>

# %%
palette1.update({'most similar': 'red', 'least similar': 'blue', 'other': 'grey'})

# %%
m = top_most_similar_i_r.copy()
ml = top_least_similar_i_r.copy()
ni = 'sel_sim_j'

ad_all.obs[ni] = 'other'
ad_all.obs.loc[ad_all.obs.index.isin(m), ni] = 'most similar'
ad_all.obs.loc[ad_all.obs.index.isin(ml), ni] = 'least similar'

plt.rcParams["figure.figsize"] = (5,5)
sc.pl.umap(ad_all, color=['cluster', ni], palette=palette1, size=20)

plt.rcParams["figure.figsize"] = (4,4)
for sample in ['WM4007_T0_S1_ST', 'WM4007_T0_S2_ST']:
    ads[sample] = ad_all[ad_all.obs['sample']==sample, :].copy()    
    ads[sample].uns['spatial'] = images[sample]
    sc.pl.spatial(ads[sample], color=['cluster', ni], palette=palette1, title=sample, spot_size=450)
# Out:
# WARNING: The title list is shorter than the number of panels. Using 'color' value instead for some plots.
# WARNING: The title list is shorter than the number of panels. Using 'color' value instead for some plots.

# %% [markdown]
# # Pseudotime T0 axis on 0, 1 and 2

# %%
ad_sel = ad_all[ad_all.obs['T'].isin(['T0']) & ad_all.obs['cluster'].isin(['0', '1', '2', '5', '6', '9'])].copy()
ad_sel = ad_sel[:, ad_sel.var['is_human_gene'].values]
sc.pp.highly_variable_genes(ad_sel, flavor="seurat", batch_key='sample', n_top_genes=200)
sc.pp.pca(ad_sel, n_comps=30, zero_center=True, use_highly_variable=True)
sce.pp.harmony_integrate(ad_sel, 'sample')
sc.pp.neighbors(ad_sel, use_rep='X_pca_harmony')
sc.tl.umap(ad_sel)
# Out:
# 2023-03-20 09:58:46,520 - harmonypy - INFO - Iteration 1 of 10
# 2023-03-20 09:58:47,087 - harmonypy - INFO - Iteration 2 of 10
# 2023-03-20 09:58:47,662 - harmonypy - INFO - Iteration 3 of 10
# 2023-03-20 09:58:48,240 - harmonypy - INFO - Iteration 4 of 10
# 2023-03-20 09:58:48,676 - harmonypy - INFO - Iteration 5 of 10
# 2023-03-20 09:58:48,904 - harmonypy - INFO - Iteration 6 of 10
# 2023-03-20 09:58:49,092 - harmonypy - INFO - Iteration 7 of 10
# 2023-03-20 09:58:49,337 - harmonypy - INFO - Iteration 8 of 10
# 2023-03-20 09:58:49,523 - harmonypy - INFO - Converged after 8 iterations

# %%
sc.pl.umap(ad_sel, color=['cluster', 'sel_sim_j'])

# %%
plt.rcParams["figure.figsize"] = (4,4)
sc.pl.umap(ad_sel, color=['GAPDH', 'CCND1'])

# %% [markdown]
# # Pseudotime ordering

# %%
scf.tl.curve(ad_sel, Nodes=10, use_rep="X_umap", ndims_rep=2)

plt.rcParams["figure.figsize"] = (5,5)
scf.pl.graph(ad_sel, basis="umap")

scf.tl.root(ad_sel, 'GAPDH') 

scf.tl.convert_to_soft(ad_sel, 1, 1000)
# Out:
# inferring a principal curve --> parameters used
#     10 principal points, mu = 0.1, lambda = 0.01
#     finished (0:00:00) --> added
#     .uns['epg'] dictionnary containing inferred elastic curve generated from elpigraph.
#     .obsm['X_R'] hard assignment of cells to principal points.
#     .uns['graph']['B'] adjacency matrix of the principal points.
#     .uns['graph']['F'], coordinates of principal points in representation space.
# automatic root selection using GAPDH values
# node 0 selected as a root --> added
#     .uns['graph']['root'] selected root.
#     .uns['graph']['pp_info'] for each PP, its distance vs root and segment assignment.
#     .uns['graph']['pp_seg'] segments network information.
# Converting R into soft assignment matrix
#     finished (0:00:00) --> updated
#     .obsm['X_R'] converted soft assignment of cells to principal points.
#     .uns['graph']['F'] coordinates of principal points in representation space.

# %%
scf.tl.pseudotime(ad_sel, n_jobs=6, n_map=100, seed=42)
# Out:
# projecting cells onto the principal graph
#     mappings: 100%|██████████████████████████████████████████████████████████████████| 100/100 [05:04<00:00,  3.05s/it]
#     finished (0:05:06) --> added
#     .obs['edge'] assigned edge.
#     .obs['t'] pseudotime value.
#     .obs['seg'] segment of the tree assigned.
#     .obs['milestones'] milestone assigned.
#     .uns['pseudotime_list'] list of cell projection from all mappings.

# %%
plt.rcParams["figure.figsize"] = (5,5)
scf.pl.trajectory(ad_sel, basis="umap", arrows=True, arrow_offset=1)
sc.pl.umap(ad_sel, color=['t'])

# %%
plt.rcParams["figure.figsize"] = (4,4)
for sample in ['WM4007_T0_S1_ST', 'WM4007_T0_S2_ST']:
    ad = ad_sel[ad_sel.obs['sample']==sample]
    sc.pl.spatial(ad, color=['t'], palette=palette1, title=sample, spot_size=450)

# %%
gene_list_names = ['WP_GLYCOLYSIS_AND_GLUCONEOGENESIS', 'CELL_CYCLE', 'OXPHOS', 'PID_HIF1_TFPATHWAY']

plt.rcParams["figure.figsize"] = (8,6)

for sample in ['WM4007_T0_S1_ST', 'WM4007_T0_S2_ST']:
    print(sample)
    ad = ad_sel[ad_sel.obs['sample']==sample].copy()
    for gene_list_name in gene_list_names:
        sn = 'score_%s' % gene_list_name
        if not sn in ad.obs.columns:
            score_genes(ad, gene_list=ad.var.index.intersection(genesDicts[gene_list_name]), score_name=sn, ctrl_size=50)
    
    def addScatterAndSpline(x, y, label=''):
        order = np.argsort(x)
        x, y = x[order], y[order]
        plt.scatter(x, y, s=2)
        
        xs = np.linspace(min(x), max(x), 1000)
        spline_data = np.vstack((xs, UnivariateSpline(x, y, k=1, s=10)(xs))).T
        sg = scipy.signal.savgol_filter(spline_data.T[1], 300, 1)
        plt.plot(spline_data.T[0], sg, lw=3, alpha=0.75,
                 path_effects=[path_effects.Stroke(linewidth=5, foreground='grey'), path_effects.Normal()],
                label=label)
        
        return
    
    ad.obs['score_CELL_CYCLE_over_PID_HIF1_TFPATHWAY'] = np.log(ad.obs['score_CELL_CYCLE'] / ad.obs['score_PID_HIF1_TFPATHWAY'])
    ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS_over_OXPHOS'] = np.log(ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS'] / ad.obs['score_OXPHOS'])
    
    addScatterAndSpline(ad.obs['t'], ad.obs['score_CELL_CYCLE_over_PID_HIF1_TFPATHWAY'], label=sample + ': cell cycle / hypoxia')
    addScatterAndSpline(ad.obs['t'], ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS_over_OXPHOS'], label=sample + ': glycolysis / ox.phos')
    
    plt.xlabel('Pseudotemporal ordering', fontsize=18)
    plt.ylabel('Gene set score ratio', fontsize=18)
    plt.ylim([-2.5,1.5])
    plt.legend(fontsize=14)
# Out:
# WM4007_T0_S1_ST
# WM4007_T0_S2_ST

# %% [markdown]
# # Pseudotime T1

# %%
ad_sel = ad_all[ad_all.obs['T'].isin(['T1'])].copy()
ad_sel = ad_sel[:, ad_sel.var['is_human_gene'].values]
sc.pp.highly_variable_genes(ad_sel, flavor="seurat", batch_key='sample', n_top_genes=200)
sc.pp.pca(ad_sel, n_comps=30, zero_center=True, use_highly_variable=True)
sce.pp.harmony_integrate(ad_sel, 'sample')
sc.pp.neighbors(ad_sel, use_rep='X_pca_harmony')
sc.tl.umap(ad_sel)
# Out:
# 2023-03-20 10:04:31,418 - harmonypy - INFO - Iteration 1 of 10
# 2023-03-20 10:04:31,885 - harmonypy - INFO - Iteration 2 of 10
# 2023-03-20 10:04:32,354 - harmonypy - INFO - Iteration 3 of 10
# 2023-03-20 10:04:32,838 - harmonypy - INFO - Iteration 4 of 10
# 2023-03-20 10:04:33,299 - harmonypy - INFO - Converged after 4 iterations

# %%
plt.rcParams["figure.figsize"] = (4,4)
sc.pl.umap(ad_sel, color=['cluster'], palette=palette1) # , 'sel_sim_j'

# %%
plt.rcParams["figure.figsize"] = (4,4)
sc.pl.umap(ad_sel, color=['GAPDH', 'CCND1'])

# %%
scf.tl.curve(ad_sel, Nodes=10, use_rep="X_umap", ndims_rep=2)

plt.rcParams["figure.figsize"] = (5,5)
scf.pl.graph(ad_sel, basis="umap")

scf.tl.root(ad_sel, 'GAPDH') 

scf.tl.convert_to_soft(ad_sel, 1, 1000)
# Out:
# inferring a principal curve --> parameters used
#     10 principal points, mu = 0.1, lambda = 0.01
#     finished (0:00:00) --> added
#     .uns['epg'] dictionnary containing inferred elastic curve generated from elpigraph.
#     .obsm['X_R'] hard assignment of cells to principal points.
#     .uns['graph']['B'] adjacency matrix of the principal points.
#     .uns['graph']['F'], coordinates of principal points in representation space.
# automatic root selection using GAPDH values
# node 2 selected as a root --> added
#     .uns['graph']['root'] selected root.
#     .uns['graph']['pp_info'] for each PP, its distance vs root and segment assignment.
#     .uns['graph']['pp_seg'] segments network information.
# Converting R into soft assignment matrix
#     finished (0:00:00) --> updated
#     .obsm['X_R'] converted soft assignment of cells to principal points.
#     .uns['graph']['F'] coordinates of principal points in representation space.

# %%
scf.tl.pseudotime(ad_sel, n_jobs=6, n_map=100, seed=42)
# Out:
# projecting cells onto the principal graph
#     mappings: 100%|██████████████████████████████████████████████████████████████████| 100/100 [02:23<00:00,  1.44s/it]
#     finished (0:02:25) --> added
#     .obs['edge'] assigned edge.
#     .obs['t'] pseudotime value.
#     .obs['seg'] segment of the tree assigned.
#     .obs['milestones'] milestone assigned.
#     .uns['pseudotime_list'] list of cell projection from all mappings.

# %%
plt.rcParams["figure.figsize"] = (5,5)
scf.pl.trajectory(ad_sel, basis="umap", arrows=True, arrow_offset=1)
sc.pl.umap(ad_sel, color=['t'])

# %%
plt.rcParams["figure.figsize"] = (4,4)
for sample in ['WM4007_T1_S1_ST', 'WM4007_T1_S2_ST']:
    ad = ad_sel[ad_sel.obs['sample']==sample]
    sc.pl.spatial(ad, color=['t'], palette=palette1, title=sample, spot_size=450)

# %%
gene_list_names = ['WP_GLYCOLYSIS_AND_GLUCONEOGENESIS', 'CELL_CYCLE', 'OXPHOS', 'PID_HIF1_TFPATHWAY']

plt.rcParams["figure.figsize"] = (8,6)

for sample in ['WM4007_T1_S1_ST', 'WM4007_T1_S2_ST']:
    print(sample)
    ad = ad_sel[ad_sel.obs['sample']==sample].copy()
    for gene_list_name in gene_list_names:
        sn = 'score_%s' % gene_list_name
        if not sn in ad.obs.columns:
            score_genes(ad, gene_list=ad.var.index.intersection(genesDicts[gene_list_name]), score_name=sn, ctrl_size=50)
    
    def addScatterAndSpline(x, y, label=''):
        order = np.argsort(x)
        x, y = x[order], y[order]
        plt.scatter(x, y, s=2)
        
        xs = np.linspace(min(x), max(x), 1000)
        spline_data = np.vstack((xs, UnivariateSpline(x, y, k=1, s=10)(xs))).T
        sg = scipy.signal.savgol_filter(spline_data.T[1], 300, 1)
        plt.plot(spline_data.T[0], sg, lw=3, alpha=0.75,
                 path_effects=[path_effects.Stroke(linewidth=5, foreground='grey'), path_effects.Normal()],
                label=label)
        
        return
    
    ad.obs['score_CELL_CYCLE_over_PID_HIF1_TFPATHWAY'] = np.log(ad.obs['score_CELL_CYCLE'] / ad.obs['score_PID_HIF1_TFPATHWAY'])
    ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS_over_OXPHOS'] = np.log(ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS'] / ad.obs['score_OXPHOS'])
    
    addScatterAndSpline(ad.obs['t'], ad.obs['score_CELL_CYCLE_over_PID_HIF1_TFPATHWAY'], label=sample + ': cell cycle / hypoxia')
    addScatterAndSpline(ad.obs['t'], ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS_over_OXPHOS'], label=sample + ': glycolysis / ox.phos')
    
    plt.xlabel('Pseudotemporal ordering', fontsize=18)
    plt.ylabel('Gene set score ratio', fontsize=18)
    plt.ylim([-2.5,1.5])
    plt.legend(fontsize=14)
# Out:
# WM4007_T1_S1_ST
# WM4007_T1_S2_ST

# %%
gene_list_names = ['WP_GLYCOLYSIS_AND_GLUCONEOGENESIS', 'CELL_CYCLE', 'OXPHOS', 'PID_HIF1_TFPATHWAY']

plt.rcParams["figure.figsize"] = (7,7)

for sample in ['WM4007_T1_S1_ST', 'WM4007_T1_S2_ST'][:]:
    print(sample)
    ad = ad_sel[ad_sel.obs['sample']==sample].copy()
    for gene_list_name in gene_list_names:
        sn = 'score_%s' % gene_list_name
        if not sn in ad.obs.columns:
            score_genes(ad, gene_list=ad.var.index.intersection(genesDicts[gene_list_name]), score_name=sn, ctrl_size=50)
    
    def addScatterAndSpline(x, y, label=''):
        order = np.argsort(x)
        x, y = x[order], y[order]
        plt.scatter(x, y, s=2)
        
        xs = np.linspace(min(x), max(x), 1000)
        spline_data = np.vstack((xs, UnivariateSpline(x, y, k=1, s=10)(xs))).T
        sg = scipy.signal.savgol_filter(spline_data.T[1], 300, 1)
        plt.plot(spline_data.T[0], sg, lw=3, alpha=0.75,
                 path_effects=[path_effects.Stroke(linewidth=5, foreground='grey'), path_effects.Normal()],
                label=label)
        
        return
    
    ad.obs['score_CELL_CYCLE_over_PID_HIF1_TFPATHWAY'] = np.log(ad.obs['score_CELL_CYCLE'] / ad.obs['score_PID_HIF1_TFPATHWAY'])
    ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS_over_OXPHOS'] = np.log(ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS'] / ad.obs['score_OXPHOS'])
    
#     addScatterAndSpline(ad.obs['t'], ad.obs['score_CELL_CYCLE'], label=sample + ': cell cycle')
#     addScatterAndSpline(ad.obs['t'], ad.obs['score_PID_HIF1_TFPATHWAY'], label=sample + ': hypoxia')
#     addScatterAndSpline(ad.obs['t'], ad.obs['score_CELL_CYCLE_over_PID_HIF1_TFPATHWAY'], label=sample + ': cell cycle / hypoxia')
    
    
#     addScatterAndSpline(ad.obs['t'], ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS'], label=sample + ': glycolysis')
#     addScatterAndSpline(ad.obs['t'], ad.obs['score_OXPHOS'], label=sample + ': ox.phos')
    addScatterAndSpline(ad.obs['t'], ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS_over_OXPHOS'], label=sample + ': glycolysis / ox.phos')
    
    #addScatterAndSpline(ad.obs['t'], ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS_over_OXPHOS'], label=sample + ': glycolysis / ox.phos')
    #addScatterAndSpline(ad.obs['t'], ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS_over_OXPHOS'], label=sample + ': glycolysis / ox.phos')
    
    plt.xlabel('Pseudotemporal ordering', fontsize=18)
    plt.ylabel('Gene set score ratio', fontsize=18)
    plt.ylim([-1.6,0])
    plt.legend(fontsize=14)
# Out:
# WM4007_T1_S1_ST
# WM4007_T1_S2_ST

# %% [markdown]
# # T4

# %%
ad_sel = ad_all[ad_all.obs['T'].isin(['T4'])].copy()
ad_sel = ad_sel[ad_sel.obs['cluster'].isin(['2', '3', '8'])]
ad_sel = ad_sel[:, ad_sel.var['is_human_gene'].values]
sc.pp.highly_variable_genes(ad_sel, flavor="seurat", batch_key='sample', n_top_genes=200)
sc.pp.pca(ad_sel, n_comps=30, zero_center=True, use_highly_variable=True)
sce.pp.harmony_integrate(ad_sel, 'sample')
sc.pp.neighbors(ad_sel, use_rep='X_pca_harmony')
sc.tl.umap(ad_sel)
# Out:
# 2023-03-24 15:05:33,311 - harmonypy - INFO - Iteration 1 of 10
# 2023-03-24 15:05:33,508 - harmonypy - INFO - Iteration 2 of 10
# 2023-03-24 15:05:33,696 - harmonypy - INFO - Iteration 3 of 10
# 2023-03-24 15:05:33,868 - harmonypy - INFO - Iteration 4 of 10
# 2023-03-24 15:05:33,929 - harmonypy - INFO - Iteration 5 of 10
# 2023-03-24 15:05:33,989 - harmonypy - INFO - Iteration 6 of 10
# 2023-03-24 15:05:34,052 - harmonypy - INFO - Iteration 7 of 10
# 2023-03-24 15:05:34,114 - harmonypy - INFO - Converged after 7 iterations

# %%
plt.rcParams["figure.figsize"] = (4,4)
sc.pl.umap(ad_sel, color=['cluster'], palette=palette1)

# %%
plt.rcParams["figure.figsize"] = (4,4)
sc.pl.umap(ad_sel, color=['GAPDH', 'CCND1'])

# %%
scf.tl.curve(ad_sel, Nodes=10, use_rep="X_umap", ndims_rep=2)

plt.rcParams["figure.figsize"] = (5,5)
scf.pl.graph(ad_sel, basis="umap")

scf.tl.root(ad_sel, 'GAPDH') 

scf.tl.convert_to_soft(ad_sel, 1, 1000)
# Out:
# inferring a principal curve --> parameters used
#     10 principal points, mu = 0.1, lambda = 0.01
#     finished (0:00:00) --> added
#     .uns['epg'] dictionnary containing inferred elastic curve generated from elpigraph.
#     .obsm['X_R'] hard assignment of cells to principal points.
#     .uns['graph']['B'] adjacency matrix of the principal points.
#     .uns['graph']['F'], coordinates of principal points in representation space.
# automatic root selection using GAPDH values
# node 2 selected as a root --> added
#     .uns['graph']['root'] selected root.
#     .uns['graph']['pp_info'] for each PP, its distance vs root and segment assignment.
#     .uns['graph']['pp_seg'] segments network information.
# Converting R into soft assignment matrix
#     finished (0:00:00) --> updated
#     .obsm['X_R'] converted soft assignment of cells to principal points.
#     .uns['graph']['F'] coordinates of principal points in representation space.

# %%
scf.tl.pseudotime(ad_sel, n_jobs=6, n_map=100, seed=42)
# Out:
# projecting cells onto the principal graph
#     mappings: 100%|██████████████████████████████████████████████████████████████████| 100/100 [02:35<00:00,  1.55s/it]
#     finished (0:02:36) --> added
#     .obs['edge'] assigned edge.
#     .obs['t'] pseudotime value.
#     .obs['seg'] segment of the tree assigned.
#     .obs['milestones'] milestone assigned.
#     .uns['pseudotime_list'] list of cell projection from all mappings.

# %%
plt.rcParams["figure.figsize"] = (5,5)
scf.pl.trajectory(ad_sel, basis="umap", arrows=True, arrow_offset=1)
sc.pl.umap(ad_sel, color=['t'])

# %%
plt.rcParams["figure.figsize"] = (4,4)
for sample in ['WM4007_T4_S1_ST', 'WM4007_T4_S2_ST']:
    ad = ad_sel[ad_sel.obs['sample']==sample]
    sc.pl.spatial(ad, color=['t'], palette=palette1, title=sample, spot_size=450)

# %%
gene_list_names = ['WP_GLYCOLYSIS_AND_GLUCONEOGENESIS', 'CELL_CYCLE', 'OXPHOS', 'PID_HIF1_TFPATHWAY']

plt.rcParams["figure.figsize"] = (8,6)

for sample in ['WM4007_T4_S1_ST', 'WM4007_T4_S2_ST']:
    print(sample)
    ad = ad_sel[ad_sel.obs['sample']==sample].copy()
    for gene_list_name in gene_list_names:
        sn = 'score_%s' % gene_list_name
        if not sn in ad.obs.columns:
            score_genes(ad, gene_list=ad.var.index.intersection(genesDicts[gene_list_name]), score_name=sn, ctrl_size=50)
    
    def addScatterAndSpline(x, y, label=''):
        order = np.argsort(x)
        x, y = x[order], y[order]
        plt.scatter(x, y, s=2)
        
        xs = np.linspace(min(x), max(x), 1000)
        spline_data = np.vstack((xs, UnivariateSpline(x, y, k=1, s=10)(xs))).T
        sg = scipy.signal.savgol_filter(spline_data.T[1], 300, 1)
        plt.plot(spline_data.T[0], sg, lw=3, alpha=0.75,
                 path_effects=[path_effects.Stroke(linewidth=5, foreground='grey'), path_effects.Normal()],
                label=label)
        
        return
    
    ad.obs['score_CELL_CYCLE_over_PID_HIF1_TFPATHWAY'] = np.log(ad.obs['score_CELL_CYCLE'] / ad.obs['score_PID_HIF1_TFPATHWAY'])
    ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS_over_OXPHOS'] = np.log(ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS'] / ad.obs['score_OXPHOS'])
    
    addScatterAndSpline(ad.obs['t'], ad.obs['score_CELL_CYCLE_over_PID_HIF1_TFPATHWAY'], label=sample + ': cell cycle / hypoxia')
    addScatterAndSpline(ad.obs['t'], ad.obs['score_WP_GLYCOLYSIS_AND_GLUCONEOGENESIS_over_OXPHOS'], label=sample + ': glycolysis / ox.phos')
    
    plt.xlabel('Pseudotemporal ordering', fontsize=18)
    plt.ylabel('Gene set score ratio', fontsize=18)
#     plt.ylim([-2.5,1.5])
    plt.legend(fontsize=14)
# Out:
# WM4007_T4_S1_ST
# WM4007_T4_S2_ST
